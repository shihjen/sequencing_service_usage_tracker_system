# %%
# import required libraries
import pandas as pd
import numpy as np
import os

# %%
def trim_dataframe(df):
    # Create a boolean mask where 'Subtotal' is present
    mask = df.apply(lambda row: row.astype(str).str.contains('Subtotal')).any(axis=1)
    
    # Find the index of the first occurrence of 'Subtotal'
    if mask.any():
        subtotal_index = mask.idxmax()  # Get the index of the first True value
        
        # Return the DataFrame up to the row before 'Subtotal'
        trimmed_df = df.iloc[:subtotal_index-1]
    else:
        # If 'Subtotal' is not found, return the original DataFrame
        trimmed_df = df
    
    return trimmed_df

# %%
# directory containing HTML files
html_dir = '../data/html_data'

# List to store DataFrames
html_dfs = []

# iterate over files in the directory
for file in os.listdir(html_dir):
    if file.endswith('.html'):
        # Construct the full path to the HTML file
        file_path = os.path.join(html_dir, file)
        
        # Read HTML tables from the file
        tables = pd.read_html(file_path)
        
        # Append the DataFrames to the list
        html_dfs.extend(tables)
        
print('Number of table extracted:', len(html_dfs))
# Out:
# Number of table extracted: 74

# %%
processed_dfs = []
for df in html_dfs:
    trimmed_df = trim_dataframe(df.iloc[1:,:])
    processed_dfs.append(trimmed_df.iloc[:,:2])

# %%
cont = []
for df in processed_dfs:
    if df.shape[0] == 0:
        continue
    else:
        if '[' in df.iloc[0, 0]:
            cont.append(df)

# %%
merged_data = pd.concat(cont, axis=0)
merged_data.columns = ['Description', 'Number_Samples']

# %%
# extract the order ID and order date from the description column
merged_data['Order_ID'] = merged_data['Description'].apply(lambda x: x.split(' ')[0]).str.strip('[').str.strip(']')

merged_data['Order_Date'] = merged_data['Order_ID'].apply(lambda x: x.split('F')[0])
merged_data['Order_Date'] = pd.to_datetime(merged_data['Order_Date'], format='%y%m%d')
merged_data['Order_Date'] = merged_data['Order_Date'].dt.strftime('%Y-%m-%d')

# %%
# subset the dataframe with selected column, sort by date and export into Excel file
invoice = merged_data[['Order_ID','Order_Date','Number_Samples']]
sorted_invoice = invoice.sort_values(by='Order_Date')
sorted_invoice.to_excel('../data/macrogen_invoice.xlsx', index=False)

# %%
html = pd.read_html('../data/html_data/old/ISC200228229.html')
print(len(html))
# Out:
# 2

# %%
html[0]
# Out:
#                0                       1     2         3           4  \
# 0      Order No.     Service description  Q'ty      Unit  Unit price
# 1   200131FN-090      Plasmid Sequencing     4  Reaction         4.6
# 2   200131FN-088  PCR product Sequencing    11  Reaction         4.6
# 3   200131FN-094  PCR product Sequencing     8  Reaction         4.6
# 4   200203FN-038  PCR product Sequencing     3  Reaction         4.6
# 5   200203FN-037      Plasmid Sequencing     4  Reaction         4.6
# 6   200204FN-048  PCR product Sequencing    12  Reaction         4.6
# 7   200205FN-086  PCR product Sequencing    12  Reaction         4.6
# 8   200206FN-079  PCR product Sequencing     4  Reaction         4.6
# 9   200207FN-076  PCR product Sequencing     8  Reaction         4.6
# 10  200210FN-027  PCR product Sequencing     4  Reaction         4.6
# 11  200210FN-025  PCR product Sequencing    11  Reaction         4.6
# 12  200210FN-026      Plasmid Sequencing     4  Reaction         4.6
#
#                5
# 0   Amount (SGD)
# 1           18.4
# 2           50.6
# 3           36.8
# 4           13.8
# 5           18.4
# 6           55.2
# 7           55.2
# 8           18.4
# 9           36.8
# 10          18.4
# 11          50.6
# 12          18.4

# %%
html[1]
# Out:
#                0                       1      2         3      4       5
# 0   200211FN-126  PCR product Sequencing      4  Reaction    4.6    18.4
# 1   200212FN-067      Plasmid Sequencing      2  Reaction    4.6     9.2
# 2   200214FN-049  PCR product Sequencing      8  Reaction    4.6    36.8
# 3   200214FN-057  PCR product Sequencing     12  Reaction    4.6    55.2
# 4   200217FN-012  PCR product Sequencing      4  Reaction    4.6    18.4
# 5   200217FN-105  PCR product Sequencing     12  Reaction    4.6    55.2
# 6   200218FN-052  PCR product Sequencing      1  Reaction    4.6     4.6
# 7   200218FN-084  PCR product Sequencing      6  Reaction    4.6    27.6
# 8   200220FN-064  PCR product Sequencing      4  Reaction    4.6    18.4
# 9   200220FN-107  PCR product Sequencing     26  Reaction    4.6   119.6
# 10  200221FN-084  PCR product Sequencing      4  Reaction    4.6    18.4
# 11  200221FN-085  PCR product Sequencing     12  Reaction    4.6    55.2
# 12  200225FN-038  PCR product Sequencing     26  Reaction    4.6   119.6
# 13  200225FN-049  PCR product Sequencing     18  Reaction    4.6    82.8
# 14  200226FN-024  PCR product Sequencing     12  Reaction    4.6    55.2
# 15  200227FN-046  PCR product Sequencing     28  Reaction    4.6   128.8
# 16         Total                   Total  Total     Total  Total  1214.4

# %%
merged = pd.concat([html[0], html[1]], axis=0)
merged
# Out:
#                0                       1      2         3           4  \
# 0      Order No.     Service description   Q'ty      Unit  Unit price
# 1   200131FN-090      Plasmid Sequencing      4  Reaction         4.6
# 2   200131FN-088  PCR product Sequencing     11  Reaction         4.6
# 3   200131FN-094  PCR product Sequencing      8  Reaction         4.6
# 4   200203FN-038  PCR product Sequencing      3  Reaction         4.6
# 5   200203FN-037      Plasmid Sequencing      4  Reaction         4.6
# 6   200204FN-048  PCR product Sequencing     12  Reaction         4.6
# 7   200205FN-086  PCR product Sequencing     12  Reaction         4.6
# 8   200206FN-079  PCR product Sequencing      4  Reaction         4.6
# 9   200207FN-076  PCR product Sequencing      8  Reaction         4.6
# 10  200210FN-027  PCR product Sequencing      4  Reaction         4.6
# 11  200210FN-025  PCR product Sequencing     11  Reaction         4.6
# 12  200210FN-026      Plasmid Sequencing      4  Reaction         4.6
# 0   200211FN-126  PCR product Sequencing      4  Reaction         4.6
# 1   200212FN-067      Plasmid Sequencing      2  Reaction         4.6
# 2   200214FN-049  PCR product Sequencing      8  Reaction         4.6
# 3   200214FN-057  PCR product Sequencing     12  Reaction         4.6
# 4   200217FN-012  PCR product Sequencing      4  Reaction         4.6
# 5   200217FN-105  PCR product Sequencing     12  Reaction         4.6
# 6   200218FN-052  PCR product Sequencing      1  Reaction         4.6
# 7   200218FN-084  PCR product Sequencing      6  Reaction         4.6
# 8   200220FN-064  PCR product Sequencing      4  Reaction         4.6
# 9   200220FN-107  PCR product Sequencing     26  Reaction         4.6
# 10  200221FN-084  PCR product Sequencing      4  Reaction         4.6
# 11  200221FN-085  PCR product Sequencing     12  Reaction         4.6
# 12  200225FN-038  PCR product Sequencing     26  Reaction         4.6
# 13  200225FN-049  PCR product Sequencing     18  Reaction         4.6
# 14  200226FN-024  PCR product Sequencing     12  Reaction         4.6
# 15  200227FN-046  PCR product Sequencing     28  Reaction         4.6
# 16         Total                   Total  Total     Total       Total
#
#                5
# 0   Amount (SGD)
# 1           18.4
# 2           50.6
# 3           36.8
# 4           13.8
# 5           18.4
# 6           55.2
# 7           55.2
# 8           18.4
# 9           36.8
# 10          18.4
# 11          50.6
# 12          18.4
# 0           18.4
# 1            9.2
# 2           36.8
# 3           55.2
# 4           18.4
# 5           55.2
# 6            4.6
# 7           27.6
# 8           18.4
# 9          119.6
# 10          18.4
# 11          55.2
# 12         119.6
# 13          82.8
# 14          55.2
# 15         128.8
# 16        1214.4

# %%
merged = merged.iloc[1:-1, :].copy()

# %%
merged.columns = ['Order_ID', 'Description', 'Number_Samples', 'UOM', 'Unit_Price', 'Total']

# %%
merged_subset = merged[~merged['Order_ID'].isna()].copy()

# %%
merged_subset
# Out:
#         Order_ID             Description Number_Samples       UOM Unit_Price  \
# 1   200131FN-090      Plasmid Sequencing              4  Reaction        4.6
# 2   200131FN-088  PCR product Sequencing             11  Reaction        4.6
# 3   200131FN-094  PCR product Sequencing              8  Reaction        4.6
# 4   200203FN-038  PCR product Sequencing              3  Reaction        4.6
# 5   200203FN-037      Plasmid Sequencing              4  Reaction        4.6
# 6   200204FN-048  PCR product Sequencing             12  Reaction        4.6
# 7   200205FN-086  PCR product Sequencing             12  Reaction        4.6
# 8   200206FN-079  PCR product Sequencing              4  Reaction        4.6
# 9   200207FN-076  PCR product Sequencing              8  Reaction        4.6
# 10  200210FN-027  PCR product Sequencing              4  Reaction        4.6
# 11  200210FN-025  PCR product Sequencing             11  Reaction        4.6
# 12  200210FN-026      Plasmid Sequencing              4  Reaction        4.6
# 0   200211FN-126  PCR product Sequencing              4  Reaction        4.6
# 1   200212FN-067      Plasmid Sequencing              2  Reaction        4.6
# 2   200214FN-049  PCR product Sequencing              8  Reaction        4.6
# 3   200214FN-057  PCR product Sequencing             12  Reaction        4.6
# 4   200217FN-012  PCR product Sequencing              4  Reaction        4.6
# 5   200217FN-105  PCR product Sequencing             12  Reaction        4.6
# 6   200218FN-052  PCR product Sequencing              1  Reaction        4.6
# 7   200218FN-084  PCR product Sequencing              6  Reaction        4.6
# 8   200220FN-064  PCR product Sequencing              4  Reaction        4.6
# 9   200220FN-107  PCR product Sequencing             26  Reaction        4.6
# 10  200221FN-084  PCR product Sequencing              4  Reaction        4.6
# 11  200221FN-085  PCR product Sequencing             12  Reaction        4.6
# 12  200225FN-038  PCR product Sequencing             26  Reaction        4.6
# 13  200225FN-049  PCR product Sequencing             18  Reaction        4.6
# 14  200226FN-024  PCR product Sequencing             12  Reaction        4.6
# 15  200227FN-046  PCR product Sequencing             28  Reaction        4.6
#
#     Total
# 1    18.4
# 2    50.6
# 3    36.8
# 4    13.8
# 5    18.4
# 6    55.2
# 7    55.2
# 8    18.4
# 9    36.8
# 10   18.4
# 11   50.6
# 12   18.4
# 0    18.4
# 1     9.2
# 2    36.8
# 3    55.2
# 4    18.4
# 5    55.2
# 6     4.6
# 7    27.6
# 8    18.4
# 9   119.6
# 10   18.4
# 11   55.2
# 12  119.6
# 13   82.8
# 14   55.2
# 15  128.8

# %%
# extract the order ID and order date from the description column
#merged_subset['Order_ID'] = merged_subset['Description'].apply(lambda x: x.split(' ')[0]).str.strip('[').str.strip(']')

merged_subset['Order_Date'] = merged_subset['Order_ID'].apply(lambda x: x.split('F')[0])
merged_subset['Order_Date'] = pd.to_datetime(merged_subset['Order_Date'], format='%y%m%d')
merged_subset['Order_Date'] = merged_subset['Order_Date'].dt.strftime('%Y-%m-%d')

# %%
merged_subset
# Out:
#         Order_ID             Description Number_Samples       UOM Unit_Price  \
# 1   200131FN-090      Plasmid Sequencing              4  Reaction        4.6
# 2   200131FN-088  PCR product Sequencing             11  Reaction        4.6
# 3   200131FN-094  PCR product Sequencing              8  Reaction        4.6
# 4   200203FN-038  PCR product Sequencing              3  Reaction        4.6
# 5   200203FN-037      Plasmid Sequencing              4  Reaction        4.6
# 6   200204FN-048  PCR product Sequencing             12  Reaction        4.6
# 7   200205FN-086  PCR product Sequencing             12  Reaction        4.6
# 8   200206FN-079  PCR product Sequencing              4  Reaction        4.6
# 9   200207FN-076  PCR product Sequencing              8  Reaction        4.6
# 10  200210FN-027  PCR product Sequencing              4  Reaction        4.6
# 11  200210FN-025  PCR product Sequencing             11  Reaction        4.6
# 12  200210FN-026      Plasmid Sequencing              4  Reaction        4.6
# 0   200211FN-126  PCR product Sequencing              4  Reaction        4.6
# 1   200212FN-067      Plasmid Sequencing              2  Reaction        4.6
# 2   200214FN-049  PCR product Sequencing              8  Reaction        4.6
# 3   200214FN-057  PCR product Sequencing             12  Reaction        4.6
# 4   200217FN-012  PCR product Sequencing              4  Reaction        4.6
# 5   200217FN-105  PCR product Sequencing             12  Reaction        4.6
# 6   200218FN-052  PCR product Sequencing              1  Reaction        4.6
# 7   200218FN-084  PCR product Sequencing              6  Reaction        4.6
# 8   200220FN-064  PCR product Sequencing              4  Reaction        4.6
# 9   200220FN-107  PCR product Sequencing             26  Reaction        4.6
# 10  200221FN-084  PCR product Sequencing              4  Reaction        4.6
# 11  200221FN-085  PCR product Sequencing             12  Reaction        4.6
# 12  200225FN-038  PCR product Sequencing             26  Reaction        4.6
# 13  200225FN-049  PCR product Sequencing             18  Reaction        4.6
# 14  200226FN-024  PCR product Sequencing             12  Reaction        4.6
# 15  200227FN-046  PCR product Sequencing             28  Reaction        4.6
#
#     Total  Order_Date
# 1    18.4  2020-01-31
# 2    50.6  2020-01-31
# 3    36.8  2020-01-31
# 4    13.8  2020-02-03
# 5    18.4  2020-02-03
# 6    55.2  2020-02-04
# 7    55.2  2020-02-05
# 8    18.4  2020-02-06
# 9    36.8  2020-02-07
# 10   18.4  2020-02-10
# 11   50.6  2020-02-10
# 12   18.4  2020-02-10
# 0    18.4  2020-02-11
# 1     9.2  2020-02-12
# 2    36.8  2020-02-14
# 3    55.2  2020-02-14
# 4    18.4  2020-02-17
# 5    55.2  2020-02-17
# 6     4.6  2020-02-18
# 7    27.6  2020-02-18
# 8    18.4  2020-02-20
# 9   119.6  2020-02-20
# 10   18.4  2020-02-21
# 11   55.2  2020-02-21
# 12  119.6  2020-02-25
# 13   82.8  2020-02-25
# 14   55.2  2020-02-26
# 15  128.8  2020-02-27

# %%
merged_subset2 = merged_subset[['Order_ID', 'Order_Date', 'Number_Samples']]

# %%
merged_subset2.to_excel('../data/manualinsert.xlsx', index=False)
